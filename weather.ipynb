# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
weather=pd.read_csv('/content/drive/MyDrive/weather.csv',index_col='DATE')

# %%
weather
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...                 ...                                   ...   ...   ...
# 2024-06-21  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-06-22  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-06-23  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-06-24  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-06-25  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
# ...

# %%
core_weather=weather[['PRCP','SNOW','SNWD','TMAX','TMIN','ACMH','AWND']].copy()

# %%
core_weather
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN  ACMH   AWND
# DATE
# 1960-01-01   0.0   0.0   0.0  49.0  30.0   NaN    NaN
# 1960-01-02   0.0   0.0   0.0  49.0  29.0   NaN    NaN
# 1960-01-03   0.0   0.0   0.0  54.0  35.0   NaN    NaN
# 1960-01-04   0.0   0.0   0.0  54.0  36.0   NaN    NaN
# 1960-01-05   0.0   0.0   0.0  55.0  33.0   NaN    NaN
# ...          ...   ...   ...   ...   ...   ...    ...
# 2024-06-21   0.0   NaN   NaN  70.0  54.0   NaN  10.96
# 2024-06-22   0.0   NaN   NaN  76.0  55.0   NaN   7.61
# 2024-06-23   0.0   NaN   NaN  71.0  56.0   NaN  11.41
# 2024-06-24   0.0   NaN   NaN  79.0  53.0   NaN   8.28
# 2024-06-25   0.0   NaN   NaN  75.0  55.0   NaN    NaN
#
# [17739 rows x 7 columns]

# %%
core_weather.columns=['Precipitation','snow','snow_depth','max_temp','min_temp','cloudiness','wind_speed']

# %%
core_weather
# Out:
#             Precipitation  snow  snow_depth  max_temp  min_temp  cloudiness  \
# DATE
# 1960-01-01            0.0   0.0         0.0      49.0      30.0         NaN
# 1960-01-02            0.0   0.0         0.0      49.0      29.0         NaN
# 1960-01-03            0.0   0.0         0.0      54.0      35.0         NaN
# 1960-01-04            0.0   0.0         0.0      54.0      36.0         NaN
# 1960-01-05            0.0   0.0         0.0      55.0      33.0         NaN
# ...                   ...   ...         ...       ...       ...         ...
# 2024-06-21            0.0   NaN         NaN      70.0      54.0         NaN
# 2024-06-22            0.0   NaN         NaN      76.0      55.0         NaN
# 2024-06-23            0.0   NaN         NaN      71.0      56.0         NaN
# 2024-06-24            0.0   NaN         NaN      79.0      53.0         NaN
# 2024-06-25            0.0   NaN         NaN      75.0      55.0         NaN
#
#             wind_speed
# DATE
# ...

# %%
core_weather['snow'].value_counts()
# Out:
# snow
# 0.0    11379
# 1.0        1
# Name: count, dtype: int64

# %%
del core_weather['snow']

# %%
core_weather['snow_depth'].value_counts()
# Out:
# snow_depth
# 0.0    11504
# Name: count, dtype: int64

# %%
del core_weather['snow_depth']

# %%
core_weather['cloudiness'].value_counts()
# Out:
# cloudiness
# 0.0      894
# 40.0     565
# 50.0     531
# 60.0     531
# 30.0     515
# 100.0    503
# 90.0     475
# 70.0     472
# 80.0     467
# 10.0     457
# 20.0     434
# Name: count, dtype: int64

# %%
core_weather['wind_speed'].value_counts()
# Out:
# wind_speed
# 8.50     274
# 7.61     274
# 9.17     266
# 5.82     253
# 6.71     249
#         ...
# 22.37      1
# 24.83      1
# 23.26      1
# 22.59      1
# 23.04      1
# Name: count, Length: 99, dtype: int64

# %%
core_weather['Precipitation'].value_counts()
# Out:
# Precipitation
# 0.00    14401
# 0.01      445
# 0.02      205
# 0.03      126
# 0.05      105
#         ...
# 1.38        1
# 1.95        1
# 2.01        1
# 1.41        1
# 1.28        1
# Name: count, Length: 179, dtype: int64

# %%
core_weather['max_temp'].value_counts()
# Out:
# max_temp
# 68.0     881
# 67.0     877
# 60.0     866
# 65.0     845
# 66.0     842
#         ...
# 122.0      1
# 107.0      1
# 38.0       1
# 39.0       1
# 102.0      1
# Name: count, Length: 67, dtype: int64

# %%
core_weather[pd.isnull(core_weather['max_temp'])]
# Out:
#             Precipitation  max_temp  min_temp  cloudiness  wind_speed
# DATE
# 2004-11-20            NaN       NaN       NaN         NaN       10.07
# 2013-06-16            0.0       NaN       NaN         NaN        8.50
# 2019-04-18            0.0       NaN      50.0         NaN        5.59
# 2019-04-21            0.0       NaN      52.0         NaN        8.28
# 2019-04-22            0.0       NaN      50.0         NaN        5.82
# 2020-08-29            0.0       NaN       NaN         NaN        9.84
# 2020-09-08            0.0       NaN       NaN         NaN        6.93
# 2020-09-09            0.0       NaN       NaN         NaN        4.70
# 2021-10-31            0.0       NaN      56.0         NaN        6.71
# 2022-10-08            0.0       NaN       NaN         NaN        7.38
# 2022-10-09            0.0       NaN       NaN         NaN        7.61

# %%
core_weather=core_weather.fillna(method='ffill')

# %%
core_weather[pd.isnull(core_weather['max_temp'])]
# Out:
# Empty DataFrame
# Columns: [Precipitation, max_temp, min_temp, cloudiness, wind_speed]
# Index: []

# %%
core_weather[pd.isnull(core_weather['cloudiness'])]
# Out:
#             Precipitation  max_temp  min_temp  cloudiness  wind_speed
# DATE
# 1960-01-01           0.00      49.0      30.0         NaN         NaN
# 1960-01-02           0.00      49.0      29.0         NaN         NaN
# 1960-01-03           0.00      54.0      35.0         NaN         NaN
# 1960-01-04           0.00      54.0      36.0         NaN         NaN
# 1960-01-05           0.00      55.0      33.0         NaN         NaN
# ...                   ...       ...       ...         ...         ...
# 1964-12-27           0.34      56.0      48.0         NaN         NaN
# 1964-12-28           0.14      51.0      45.0         NaN         NaN
# 1964-12-29           0.92      50.0      45.0         NaN         NaN
# 1964-12-30           0.52      50.0      43.0         NaN         NaN
# 1964-12-31           0.10      49.0      38.0         NaN         NaN
#
# [1827 rows x 5 columns]

# %%
cols_to_fill_zero=['wind_speed','cloudiness']
core_weather[cols_to_fill_zero]=core_weather[cols_to_fill_zero].fillna(0)

# %%
core_weather.isna().sum()
# Out:
# Precipitation    0
# max_temp         0
# min_temp         0
# cloudiness       0
# wind_speed       0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# Precipitation    float64
# max_temp         float64
# min_temp         float64
# cloudiness       float64
# wind_speed       float64
# dtype: object

# %%
core_weather.index=pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2024-06-16', '2024-06-17', '2024-06-18', '2024-06-19',
#                '2024-06-20', '2024-06-21', '2024-06-22', '2024-06-23',
#                '2024-06-24', '2024-06-25'],
#               dtype='datetime64[ns]', name='DATE', length=17739, freq=None)

# %%
core_weather.index.year
# Out:
# Index([1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960,
#        ...
#        2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024],
#       dtype='int32', name='DATE', length=17739)

# %%
core_weather.apply(lambda x:(x==9999).sum())
# Out:
# Precipitation    0
# max_temp         0
# min_temp         0
# cloudiness       0
# wind_speed       0
# dtype: int64

# %%
core_weather[['max_temp','min_temp']]
# Out:
#             max_temp  min_temp
# DATE
# 1960-01-01      49.0      30.0
# 1960-01-02      49.0      29.0
# 1960-01-03      54.0      35.0
# 1960-01-04      54.0      36.0
# 1960-01-05      55.0      33.0
# ...              ...       ...
# 2024-06-21      70.0      54.0
# 2024-06-22      76.0      55.0
# 2024-06-23      71.0      56.0
# 2024-06-24      79.0      53.0
# 2024-06-25      75.0      55.0
#
# [17739 rows x 2 columns]

# %%
core_weather[['max_temp','min_temp']].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.month).sum()
# Out:
#       Precipitation  max_temp  min_temp  cloudiness  wind_speed
# DATE
# 1            152.47   86355.0   64795.0     53680.0     4722.73
# 2            136.07   83132.0   62796.0     51050.0     5340.06
# 3            121.87   94523.0   71862.0     52160.0     6705.53
# 4             63.84   94899.0   72146.0     47360.0     7414.15
# 5             16.60  102008.0   79155.0     46950.0     8058.64
# 6              6.92  102991.0   80258.0     46230.0     7504.48
# 7              1.69  107901.0   85818.0     45930.0     7380.89
# 8              1.44  107175.0   85245.0     46150.0     6855.30
# 9              7.05  106465.0   81331.0     42460.0     5797.99
# 10            57.33  105061.0   78636.0     44710.0     5075.45
# 11           113.35   90655.0   67810.0     48530.0     4216.19
# 12           168.19   84393.0   63926.0     49990.0     4799.40

# %%
core_weather['target']=core_weather.shift(-1)['max_temp']

# %%
core_weather
# Out:
#             Precipitation  max_temp  min_temp  cloudiness  wind_speed  target
# DATE
# 1960-01-01            0.0      49.0      30.0         0.0        0.00    49.0
# 1960-01-02            0.0      49.0      29.0         0.0        0.00    54.0
# 1960-01-03            0.0      54.0      35.0         0.0        0.00    54.0
# 1960-01-04            0.0      54.0      36.0         0.0        0.00    55.0
# 1960-01-05            0.0      55.0      33.0         0.0        0.00    53.0
# ...                   ...       ...       ...         ...         ...     ...
# 2024-06-21            0.0      70.0      54.0        30.0       10.96    76.0
# 2024-06-22            0.0      76.0      55.0        30.0        7.61    71.0
# 2024-06-23            0.0      71.0      56.0        30.0       11.41    79.0
# 2024-06-24            0.0      79.0      53.0        30.0        8.28    75.0
# 2024-06-25            0.0      75.0      55.0        30.0        8.28     NaN
#
# [17739 rows x 6 columns]

# %%
core_weather=core_weather.iloc[:-1].copy()

# %%
core_weather
# Out:
#             Precipitation  max_temp  min_temp  cloudiness  wind_speed  target
# DATE
# 1960-01-01            0.0      49.0      30.0         0.0        0.00    49.0
# 1960-01-02            0.0      49.0      29.0         0.0        0.00    54.0
# 1960-01-03            0.0      54.0      35.0         0.0        0.00    54.0
# 1960-01-04            0.0      54.0      36.0         0.0        0.00    55.0
# 1960-01-05            0.0      55.0      33.0         0.0        0.00    53.0
# ...                   ...       ...       ...         ...         ...     ...
# 2024-06-20            0.0      64.0      54.0        30.0        9.84    70.0
# 2024-06-21            0.0      70.0      54.0        30.0       10.96    76.0
# 2024-06-22            0.0      76.0      55.0        30.0        7.61    71.0
# 2024-06-23            0.0      71.0      56.0        30.0       11.41    79.0
# 2024-06-24            0.0      79.0      53.0        30.0        8.28    75.0
#
# [17738 rows x 6 columns]

# %%
from sklearn.linear_model import Ridge
reg=Ridge(alpha=.1)

# %%
predictors=['Precipitation','max_temp','min_temp','cloudiness','wind_speed']

# %%
train=core_weather.loc[:'2020-12-31']
test=core_weather.loc['2021-01-01':]

# %%
reg.fit(train[predictors],train['target'])
# Out:
# Ridge(alpha=0.1)

# %%
predictions=reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error
error=mean_absolute_error(test['target'],predictions)

# %%
error
# Out:
# 3.294944922515615

# %%
combined=pd.concat([test['target'],pd.Series(predictions,index=test.index)],axis=1)

# %%
combined.columns=['actual','predictions']

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    57.0    59.831441
# 2021-01-02    56.0    59.357106
# 2021-01-03    62.0    58.618909
# 2021-01-04    59.0    61.814457
# 2021-01-05    59.0    59.509027
# ...            ...          ...
# 2024-06-20    70.0    65.549873
# 2024-06-21    76.0    69.858257
# 2024-06-22    71.0    74.154418
# 2024-06-23    79.0    70.965086
# 2024-06-24    75.0    75.936606
#
# [1271 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
def create_predictions(predictors,reg,core_weather):
  train=core_weather.loc[:'2020-12-31']
  test=core_weather.loc['2021-01-01':]
  reg.fit(train[predictors],train['target'])
  predictions=reg.predict(test[predictors])
  error=mean_absolute_error(test['target'],predictions)
  combined=pd.concat([test['target'],pd.Series(predictions,index=test.index)],axis=1)
  combined.columns=['actual','predictions']
  return error,combined

# %%
core_weather['month_max']=core_weather['max_temp'].rolling(30).mean()

# %%
core_weather
# Out:
#             Precipitation  max_temp  min_temp  cloudiness  wind_speed  target  \
# DATE
# 1960-01-01            0.0      49.0      30.0         0.0        0.00    49.0
# 1960-01-02            0.0      49.0      29.0         0.0        0.00    54.0
# 1960-01-03            0.0      54.0      35.0         0.0        0.00    54.0
# 1960-01-04            0.0      54.0      36.0         0.0        0.00    55.0
# 1960-01-05            0.0      55.0      33.0         0.0        0.00    53.0
# ...                   ...       ...       ...         ...         ...     ...
# 2024-06-20            0.0      64.0      54.0        30.0        9.84    70.0
# 2024-06-21            0.0      70.0      54.0        30.0       10.96    76.0
# 2024-06-22            0.0      76.0      55.0        30.0        7.61    71.0
# 2024-06-23            0.0      71.0      56.0        30.0       11.41    79.0
# 2024-06-24            0.0      79.0      53.0        30.0        8.28    75.0
#
#             month_max
# ...

# %%
core_weather['month_min']=core_weather['min_temp'].rolling(30).mean()

# %%
core_weather
# Out:
#             Precipitation  max_temp  min_temp  cloudiness  wind_speed  target  \
# DATE
# 1960-01-01            0.0      49.0      30.0         0.0        0.00    49.0
# 1960-01-02            0.0      49.0      29.0         0.0        0.00    54.0
# 1960-01-03            0.0      54.0      35.0         0.0        0.00    54.0
# 1960-01-04            0.0      54.0      36.0         0.0        0.00    55.0
# 1960-01-05            0.0      55.0      33.0         0.0        0.00    53.0
# ...                   ...       ...       ...         ...         ...     ...
# 2024-06-20            0.0      64.0      54.0        30.0        9.84    70.0
# 2024-06-21            0.0      70.0      54.0        30.0       10.96    76.0
# 2024-06-22            0.0      76.0      55.0        30.0        7.61    71.0
# 2024-06-23            0.0      71.0      56.0        30.0       11.41    79.0
# 2024-06-24            0.0      79.0      53.0        30.0        8.28    75.0
#
# ...

# %%
core_weather['month_day_max']=core_weather['month_max']/core_weather['max_temp']

# %%
core_weather['month_day_min']=core_weather['month_min']/core_weather['min_temp']

# %%
core_weather['max_min']=core_weather['max_temp']/core_weather['min_temp']

# %%
core_weather=core_weather.iloc[30:].copy()

# %%
core_weather
# Out:
#             Precipitation  max_temp  min_temp  cloudiness  wind_speed  target  \
# DATE
# 1960-01-31           0.00      59.0      46.0         0.0        0.00    62.0
# 1960-02-01           0.81      62.0      51.0         0.0        0.00    59.0
# 1960-02-02           0.00      59.0      43.0         0.0        0.00    59.0
# 1960-02-03           0.20      59.0      47.0         0.0        0.00    60.0
# 1960-02-04           0.16      60.0      42.0         0.0        0.00    60.0
# ...                   ...       ...       ...         ...         ...     ...
# 2024-06-20           0.00      64.0      54.0        30.0        9.84    70.0
# 2024-06-21           0.00      70.0      54.0        30.0       10.96    76.0
# 2024-06-22           0.00      76.0      55.0        30.0        7.61    71.0
# 2024-06-23           0.00      71.0      56.0        30.0       11.41    79.0
# 2024-06-24           0.00      79.0      53.0        30.0        8.28    75.0
#
# ...

# %%
predictors=['Precipitation','max_temp','min_temp','cloudiness','wind_speed','month_max','month_min','month_day_max','month_day_min','max_min']

# %%
error,combined=create_predictions(predictors,reg,core_weather)

# %%
error
# Out:
# 3.1853966965208294

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    57.0    60.104275
# 2021-01-02    56.0    58.220280
# 2021-01-03    62.0    57.603422
# 2021-01-04    59.0    61.435755
# 2021-01-05    59.0    59.456552
# ...            ...          ...
# 2024-06-20    70.0    66.033060
# 2024-06-21    76.0    70.039240
# 2024-06-22    71.0    73.841765
# 2024-06-23    79.0    70.964013
# 2024-06-24    75.0    75.802445
#
# [1271 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather['monthly_avg'] = core_weather['max_temp'].groupby(core_weather.index.month).transform(lambda x: x.expanding(1).mean())

# %%
core_weather
# Out:
#             Precipitation  max_temp  min_temp  cloudiness  wind_speed  target  \
# DATE
# 1960-01-31           0.00      59.0      46.0         0.0        0.00    62.0
# 1960-02-01           0.81      62.0      51.0         0.0        0.00    59.0
# 1960-02-02           0.00      59.0      43.0         0.0        0.00    59.0
# 1960-02-03           0.20      59.0      47.0         0.0        0.00    60.0
# 1960-02-04           0.16      60.0      42.0         0.0        0.00    60.0
# ...                   ...       ...       ...         ...         ...     ...
# 2024-06-20           0.00      64.0      54.0        30.0        9.84    70.0
# 2024-06-21           0.00      70.0      54.0        30.0       10.96    76.0
# 2024-06-22           0.00      76.0      55.0        30.0        7.61    71.0
# 2024-06-23           0.00      71.0      56.0        30.0       11.41    79.0
# 2024-06-24           0.00      79.0      53.0        30.0        8.28    75.0
#
# ...

# %%
core_weather['day_avg'] = core_weather['max_temp'].groupby(core_weather.index.dayofyear).transform(lambda x: x.expanding(1).mean())

# %%
predictors=['Precipitation','max_temp','min_temp','cloudiness','wind_speed','month_max','month_min','month_day_max','month_day_min','max_min','monthly_avg','day_avg']

# %%
error,combined=create_predictions(predictors,reg,core_weather)

# %%
error
# Out:
# 3.1691988107483735

# %%
reg.coef_
# Out:
# array([-9.37369032e-01,  3.71717000e-01,  2.51032057e-02, -2.23725279e-03,
#         2.01402978e-02,  2.47334849e-01,  1.67129881e-01, -1.18186557e+01,
#        -5.96111953e+00,  4.56003726e+00,  1.33062979e-01,  7.80436586e-02])

# %%
core_weather.corr()['target']
# Out:
# Precipitation   -0.206792
# max_temp         0.821626
# min_temp         0.595677
# cloudiness      -0.170518
# wind_speed       0.085304
# target           1.000000
# month_max        0.688038
# month_min        0.646748
# month_day_max   -0.420600
# month_day_min   -0.012978
# max_min          0.045009
# monthly_avg      0.690757
# day_avg          0.712591
# Name: target, dtype: float64

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    57.0    59.523849
# 2021-01-02    56.0    57.411369
# 2021-01-03    62.0    56.846540
# 2021-01-04    59.0    60.729607
# 2021-01-05    59.0    58.855810
# ...            ...          ...
# 2024-06-20    70.0    66.662415
# 2024-06-21    76.0    70.451124
# 2024-06-22    71.0    74.001728
# 2024-06-23    79.0    71.083257
# 2024-06-24    75.0    75.997835
#
# [1271 rows x 2 columns]

# %%
core_weather['lag_1'] = core_weather['max_temp'].shift(1)
core_weather['lag_2'] = core_weather['max_temp'].shift(2)

# %%
core_weather
# Out:
#             Precipitation  max_temp  min_temp  cloudiness  wind_speed  target  \
# DATE
# 1960-01-31           0.00      59.0      46.0         0.0        0.00    62.0
# 1960-02-01           0.81      62.0      51.0         0.0        0.00    59.0
# 1960-02-02           0.00      59.0      43.0         0.0        0.00    59.0
# 1960-02-03           0.20      59.0      47.0         0.0        0.00    60.0
# 1960-02-04           0.16      60.0      42.0         0.0        0.00    60.0
# ...                   ...       ...       ...         ...         ...     ...
# 2024-06-20           0.00      64.0      54.0        30.0        9.84    70.0
# 2024-06-21           0.00      70.0      54.0        30.0       10.96    76.0
# 2024-06-22           0.00      76.0      55.0        30.0        7.61    71.0
# 2024-06-23           0.00      71.0      56.0        30.0       11.41    79.0
# 2024-06-24           0.00      79.0      53.0        30.0        8.28    75.0
#
# ...

# %%
core_weather = core_weather.iloc[30:].copy()

# %%
core_weather
# Out:
#             Precipitation  max_temp  min_temp  cloudiness  wind_speed  target  \
# DATE
# 1960-03-01           0.00      55.0      43.0         0.0        0.00    58.0
# 1960-03-02           0.00      58.0      40.0         0.0        0.00    62.0
# 1960-03-03           0.00      62.0      47.0         0.0        0.00    62.0
# 1960-03-04           0.00      62.0      52.0         0.0        0.00    58.0
# 1960-03-05           0.13      58.0      54.0         0.0        0.00    59.0
# ...                   ...       ...       ...         ...         ...     ...
# 2024-06-20           0.00      64.0      54.0        30.0        9.84    70.0
# 2024-06-21           0.00      70.0      54.0        30.0       10.96    76.0
# 2024-06-22           0.00      76.0      55.0        30.0        7.61    71.0
# 2024-06-23           0.00      71.0      56.0        30.0       11.41    79.0
# 2024-06-24           0.00      79.0      53.0        30.0        8.28    75.0
#
# ...
